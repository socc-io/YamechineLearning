# %%
print "hihi"
# Out:
# hihi

# %%
from pandas import Series, DataFrame

# %%
import pandas as pd

# %%
import numpy as np

# %%
obj = Series([4, 7, -5, 3])

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
 obj2 = Series([4,7,-5,3], index=['d','b','a','c'])

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
np.exp
# Out:
# <ufunc 'exp'>

# %%
np.exp(2)
# Out:
# 7.3890560989306504

# %%
np.exp(obj2)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
dict_data = {'apple' : 1, 'banana' : 2, 'chicken' : 3}

# %%
obj3 = Series(dict_data)

# %%
obj3
# Out:
# apple      1
# banana     2
# chicken    3
# dtype: int64

# %%
range(5)
# Out:
# [0, 1, 2, 3, 4]

# %%
frame = DataFrame(np.arange(8).reshape((2,4)), index=['banana','apple'],columns=['d','a','b','c'])

# %%
frame
# Out:
#         d  a  b  c
# banana  0  1  2  3
# apple   4  5  6  7

# %%
frame.sort_values(by='b', ascending=False)
# Out:
#         d  a  b  c
# apple   4  5  6  7
# banana  0  1  2  3

# %%
frame.sum(axis=1)
# Out:
# banana     6
# apple     22
# dtype: int64

# %%
data = pd.read_csv('../cvstore.csv')

# %%
data
# Out:
#           area                  company  hourly_wage area1 area2  outlier  \
# 0      강남구 삼성동               gs25 오크우드점         5600   강남구   삼성동        0
# 1      강남구 삼성동                gs25 코엑스점         5700   강남구   삼성동        0
# 2      강서구 화곡동                  gs25편의점         5600   강서구   화곡동        0
# 3      광진구 군자동                     gs25         5580   광진구   군자동        0
# 4      광진구 중곡동                gs25중곡대원점         5580   광진구   중곡동        0
# 5      구로구 구로동                gs25구로동양점         6000   구로구   구로동        0
# 6      구로구 구로동                gs25구로동양점         5580   구로구   구로동        0
# 7     동대문구 장안동                gs25장안중앙점         5600  동대문구   장안동        0
# 8      마포구 서교동               gs25 홍대아트점         5600   마포구   서교동        0
# 9     성동구 금호동4            gs25 서울숲푸르지오점         6000   성동구  금호동4        0
# 10    성북구 동소문동                gs25동소문본점         5580   성북구  동소문동        0
# 11    성북구 하월곡동             gs25 성북 푸르지오         5800   성북구  하월곡동        0
# 12     송파구 송파동                gs25송파중앙점         5600   송파구   송파동        0
# 13   영등포구 영등포동                     gs25         6300  영등포구  영등포동        0
# 14     은평구 신사동                     gs25         5580   은평구   신사동        0
# 15     종로구 관수동                gs25 국일관점         5600   종로구   관수동        0
# 16      중구 소공동                     gs25         5600    중구   소공동        0
# 17      중구 신당동                     gs25         5580    중구   신당동        0
# 18     강남구 논현동             세븐일레븐 논현11호점         6200   강남구   논현동        0
# 19     강남구 신사동    편의점/ 세븐일레븐 압구정 리갈펠리스점         5600   강남구   신사동        0
# 176    은평구 불광동                 CU 불광으뜸점         5580   은평구   불광동        0
#
#      name
# 0    gs25
# 1    gs25
# 2    gs25
# 3    gs25
# 4    gs25
# 5    gs25
# 6    gs25
# 7    gs25
# 8    gs25
# 9    gs25
# 10   gs25
# 11   gs25
# 12   gs25
# 13   gs25
# 14   gs25
# 15   gs25
# 16   gs25
# 17   gs25
# 18   7/11
# 19   7/11
# 20   7/11
# 21   7/11
# 22   7/11
# 23   7/11
# 24   7/11
# 25   7/11
# 26   7/11
# 27   7/11
# 28   7/11
# 29   7/11
# ..    ...
# 147    CU
# 148    CU
# 149    CU
# 150    CU
# 151    CU
# 152    CU
# 153    CU
# 154    CU
# 155    CU
# 156    CU
# 157    CU
# 158    CU
# 159    CU
# 160    CU
# 161    CU
# 162    CU
# 163    CU
# 164    CU
# 165    CU
# 166    CU
# 167    CU
# 168    CU
# 169    CU
# 170    CU
# 171    CU
# 172    CU
# 173    CU
# 174    CU
# 175    CU
# 176    CU
#
# [177 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 0 to 176
# Data columns (total 7 columns):
# area           177 non-null object
# company        177 non-null object
# hourly_wage    177 non-null int64
# area1          177 non-null object
# area2          177 non-null object
# outlier        177 non-null int64
# name           177 non-null object
# dtypes: int64(2), object(5)
# memory usage: 11.1+ KB

# %%
data.describe()
# Out:
#        hourly_wage  outlier
# count   177.000000      177
# mean   5787.627119        0
# std     352.318646        0
# min    5580.000000        0
# 25%    5580.000000        0
# 50%    5600.000000        0
# 75%    6000.000000        0
# max    7500.000000        0

# %%
data[data.hourly_wage > 6000]
# Out:
#           area                  company  hourly_wage area1 area2  outlier  \
# 13   영등포구 영등포동                     gs25         6300  영등포구  영등포동        0
# 18     강남구 논현동             세븐일레븐 논현11호점         6200   강남구   논현동        0
# 29     강남구 논현동                 세븐일레븐편의점         7500   강남구   논현동        0
# 30     강남구 청담동              세븐일레븐 청담그린점         6500   강남구   청담동        0
# 37     강서구 등촌동             세븐일레븐 서울호서대점         6600   강서구   등촌동        0
# 53    구로구 구로4동             세븐일레븐 구로리공원점         6500   구로구  구로4동        0
# 56     구로구 개봉동                세븐일레븐/개봉점         6200   구로구   개봉동        0
# 60      도봉구 창동                    세븐일레븐         6500   도봉구    창동        0
# 61    동대문구 장안동               세븐일레븐장안바우점         6300  동대문구   장안동        0
# 72     마포구 동교동              세븐일레븐 마포홍익점         6500   마포구   동교동        0
# 89     성동구 사근동           세븐일레븐 한양대학교병원점         6500   성동구   사근동        0
# 107  영등포구 영등포동            세븐일레븐 영등포 2호점         6200  영등포구  영등포동        0
# 121    종로구 관수동              세븐일레븐 종로관수점         6480   종로구   관수동        0
# 128    종로구 낙원동              세븐일레븐 종로제일점         6480   종로구   낙원동        0
# 133      중구 다동            세븐일레븐 무교yg타워점         6300    중구    다동        0
# 135    중구 명동2가                    세븐일레븐         6690    중구  명동2가        0
# 137     중구 북창동                세븐일레븐 북창점         6500    중구   북창동        0
# 143    강남구 신사동                  CU 로데오점         6100   강남구   신사동        0
# 145   강남구 논현1동                 CUBE pc방         6500   강남구  논현1동        0
# 151    금천구 독산동                CU 독산메이퀸점         6300   금천구   독산동        0
# 152    금천구 가산동          뚜레쥬르,CU,가산디폴리스점         6300   금천구   가산동        0
# 160   서대문구 신촌동  BGF Retail CU 신촌세브란스병원점         6900  서대문구   신촌동        0
# 161   서대문구 현저동                CU 독립문극동점         6500  서대문구   현저동        0
# 172    용산구 한남동               CU 한남리첸시아점         6600   용산구   한남동        0
# 173   용산구 이태원동               CU 이태원프리덤점         7500   용산구  이태원동        0
#
#      name
# 13   gs25
# 18   7/11
# 29   7/11
# 30   7/11
# 37   7/11
# 53   7/11
# 56   7/11
# 60   7/11
# 61   7/11
# 72   7/11
# 89   7/11
# 107  7/11
# 121  7/11
# 128  7/11
# 133  7/11
# 135  7/11
# 137  7/11
# 143    CU
# 145    CU
# 151    CU
# 152    CU
# 160    CU
# 161    CU
# 172    CU
# 173    CU

# %%
data['good_money']=data.hourly_wage.map((lambda x:x>6000))

# %%
data['good_money']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 147    False
# 148    False
# 149    False
# 150    False
# 151     True
# 152     True
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# 158    False
# 159    False
# 160     True
# 161     True
# 162    False
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173     True
# 174    False
# 175    False
# 176    False
# Name: good_money, dtype: bool

# %%
import matplotlib.pyplot as plt

# %%
 # %matplotlib inline

# %%
# %matplotlib inline

# %%
data.hourly_wage.hist(bins=40)

# %%
data.boxplot(column='hourly_wage')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff579dd1c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff579de1b10>,
#   <matplotlib.lines.Line2D at 0x7ff579ded190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff579dedd10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff579ded7d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff579a1ffd0>,
#   <matplotlib.lines.Line2D at 0x7ff579de14d0>]}

# %%
data = pd.read_csv('../iris.csv')

# %%
data
# Out:
#      species  sepal_length  sepal_width  petal_length  petal_width
# 0          0           4.9          3.0           1.4          0.2
# 1          1           6.2          2.2           4.5          1.5
# 2          2           6.7          2.5           5.8          1.8
# 3          0           5.1          3.8           1.9          0.4
# 4          1           6.0          2.7           5.1          1.6
# 5          2           7.7          3.8           6.7          2.2
# 6          0           4.6          3.6           1.0          0.2
# 7          1           5.6          2.9           3.6          1.3
# 8          2           7.6          3.0           6.6          2.1
# 9          0           5.1          3.7           1.5          0.4
# 10         1           5.6          3.0           4.5          1.5
# 11         2           5.8          2.7           5.1          1.9
# 12         0           4.8          3.4           1.6          0.2
# 13         1           6.1          2.9           4.7          1.4
# 14         2           7.4          2.8           6.1          1.9
# 15         0           5.0          3.4           1.6          0.4
# 16         1           6.3          2.5           4.9          1.5
# 17         2           6.7          3.0           5.2          2.3
# 18         0           4.3          3.0           1.1          0.1
# 19         1           6.5          2.8           4.6          1.5
# 20         2           6.3          2.8           5.1          1.5
# 21         0           4.7          3.2           1.3          0.2
# 22         1           5.9          3.2           4.8          1.8
# 23         2           6.9          3.1           5.4          2.1
# 24         0           5.4          3.7           1.5          0.2
# 25         1           6.7          3.1           4.4          1.4
# 26         2           6.5          3.0           5.5          1.8
# 27         0           5.0          3.4           1.5          0.2
# 28         1           6.8          2.8           4.8          1.4
# 29         2           6.8          3.2           5.9          2.3
# ..       ...           ...          ...           ...          ...
# 120        0           4.4          2.9           1.4          0.2
# 121        1           6.7          3.1           4.7          1.5
# 122        2           6.5          3.0           5.2          2.0
# 123        0           5.1          3.3           1.7          0.5
# 124        1           5.7          2.8           4.1          1.3
# 125        2           6.5          3.2           5.1          2.0
# 126        0           5.1          3.5           1.4          0.3
# 127        1           5.7          2.6           3.5          1.0
# 128        2           7.1          3.0           5.9          2.1
# 129        0           5.1          3.8           1.6          0.2
# 130        1           5.5          2.5           4.0          1.3
# 131        2           7.9          3.8           6.4          2.0
# 132        0           5.8          4.0           1.2          0.2
# 133        1           5.0          2.3           3.3          1.0
# 134        2           6.4          2.8           5.6          2.2
# 135        0           5.2          3.5           1.5          0.2
# 136        1           5.6          2.5           3.9          1.1
# 137        2           7.2          3.2           6.0          1.8
# 138        0           4.6          3.1           1.5          0.2
# 139        1           5.5          2.4           3.7          1.0
# 140        2           7.2          3.6           6.1          2.5
# 141        0           5.7          4.4           1.5          0.4
# 142        1           5.6          3.0           4.1          1.3
# 143        2           4.9          2.5           4.5          1.7
# 144        0           4.8          3.0           1.4          0.1
# 145        1           6.3          3.3           4.7          1.6
# 146        2           6.0          2.2           5.0          1.5
# 147        0           4.8          3.4           1.9          0.2
# 148        1           5.8          2.7           4.1          1.0
# 149        2           6.3          2.9           5.6          1.8
#
# [150 rows x 5 columns]

# %%
data.corr()
# Out:
#                species  sepal_length  sepal_width  petal_length  petal_width
# species       1.000000      0.782561    -0.419446      0.949043     0.956464
# sepal_length  0.782561      1.000000    -0.109369      0.871754     0.817954
# sepal_width  -0.419446     -0.109369     1.000000     -0.420516    -0.356544
# petal_length  0.949043      0.871754    -0.420516      1.000000     0.962757
# petal_width   0.956464      0.817954    -0.356544      0.962757     1.000000

# %%
data.cov()
# Out:
#                species  sepal_length  sepal_width  petal_length  petal_width
# species       0.671141      0.530872    -0.148993      1.371812     0.597987
# sepal_length  0.530872      0.685694    -0.039268      1.273682     0.516904
# sepal_width  -0.148993     -0.039268     0.188004     -0.321713    -0.117981
# petal_length  1.371812      1.273682    -0.321713      3.113179     1.296387
# petal_width   0.597987      0.516904    -0.117981      1.296387     0.582414
