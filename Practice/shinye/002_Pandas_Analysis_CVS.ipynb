# %%
#
# Pandas tutorial - 1 
#
# @author becxer
# @email becxer87@gmail.com
# @reference http://jsideas.net/python/2015/08/10/histogram_tutorial.html
#
from pandas import Series, DataFrame
import pandas as pd

print ("modules successfully imported")
# Out:
# modules successfully imported

# %%
# 데이터를 불러옵니다, index는 자동으로 생성되고 가장 첫번째 row 가 csv  column 의 title입니다.
data = pd.read_csv('../cvstore.csv')
data
# Out:
#           area                  company  hourly_wage area1 area2  outlier  \
# 0      강남구 삼성동               gs25 오크우드점         5600   강남구   삼성동        0
# 1      강남구 삼성동                gs25 코엑스점         5700   강남구   삼성동        0
# 2      강서구 화곡동                  gs25편의점         5600   강서구   화곡동        0
# 3      광진구 군자동                     gs25         5580   광진구   군자동        0
# 4      광진구 중곡동                gs25중곡대원점         5580   광진구   중곡동        0
# 5      구로구 구로동                gs25구로동양점         6000   구로구   구로동        0
# 6      구로구 구로동                gs25구로동양점         5580   구로구   구로동        0
# 7     동대문구 장안동                gs25장안중앙점         5600  동대문구   장안동        0
# 8      마포구 서교동               gs25 홍대아트점         5600   마포구   서교동        0
# 9     성동구 금호동4            gs25 서울숲푸르지오점         6000   성동구  금호동4        0
# 10    성북구 동소문동                gs25동소문본점         5580   성북구  동소문동        0
# 11    성북구 하월곡동             gs25 성북 푸르지오         5800   성북구  하월곡동        0
# ...

# %%
# 판다스의 기본 구조는 데이터 프레임 입니다.
# info 함수는 컬럼별 갯수와 타입, 메모리 크기 등을 보여줍니다.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 0 to 176
# Data columns (total 7 columns):
# area           177 non-null object
# company        177 non-null object
# hourly_wage    177 non-null int64
# area1          177 non-null object
# area2          177 non-null object
# outlier        177 non-null int64
# name           177 non-null object
# dtypes: int64(2), object(5)
# memory usage: 11.1+ KB

# %%
# describe 는 숫자 컬럼의 갯수와 평균, 평균, 표준편차, 최소, 25,50,75% 값, 최대값 등을 보여줍니다.
data.describe()
# Out:
#        hourly_wage  outlier
# count   177.000000      177
# mean   5787.627119        0
# std     352.318646        0
# min    5580.000000        0
# 25%    5580.000000        0
# 50%    5600.000000        0
# 75%    6000.000000        0
# max    7500.000000        0

# %%
# Company 컬럼중에 CU가 포함된 데이터만 불러옵니다.
data[data.company.str.contains('CU')]
# Out:
#           area                  company  hourly_wage area1 area2  outlier name
# 141    강남구 논현동                 CU 논현힐탑점         5600   강남구   논현동        0   CU
# 142    강남구 논현동                  CU논현한미점         6000   강남구   논현동        0   CU
# 143    강남구 신사동                  CU 로데오점         6100   강남구   신사동        0   CU
# 144   강남구 대치4동                  CU 대치본점         6000   강남구  대치4동        0   CU
# 145   강남구 논현1동                 CUBE pc방         6500   강남구  논현1동        0   CU
# 146   강북구 수유3동                  CU수유중앙점         5600   강북구  수유3동        0   CU
# 147    강서구 방화동                 CU방화오피스점         6000   강서구   방화동        0   CU
# 148    관악구 신원동                  CU신림인석점         5580   관악구   신원동        0   CU
# 149    관악구 봉천동                  CU관악상상점         5580   관악구   봉천동        0   CU
# 150    구로구 구로동         CU편의점(고대구로병원1호점)         5580   구로구   구로동        0   CU
# 151    금천구 독산동                CU 독산메이퀸점         6300   금천구   독산동        0   CU
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data.hourly_wage.hist(bins=40)

# %%
data.boxplot(column='hourly_wage')
